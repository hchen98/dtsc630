# %%
# !ls -a
# Out:
# .   DE_job_searched.csv  EDA.ipynb	     job_skills.csv
# ..  DS_job_searched.csv  .ipynb_checkpoints

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds_df = pd.read_csv("job_skills.csv")

# %%
ds_df.shape
# Out:
# (1250, 7)

# %%
ds_df.head()
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
# 3  Google            Developer Advocate, Partner Engineering
# 4  Google     Program Manager, Audio Visual (AV) Deployments
#
#                        Category                          Location  \
# 0            Program Management                         Singapore
# 1  Manufacturing & Supply Chain                   Shanghai, China
# 2           Technical Solutions       New York, NY, United States
# 3           Developer Relations  Mountain View, CA, United States
# 4            Program Management      Sunnyvale, CA, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# ...

# %%
ds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   1250 non-null   object
#  1   Title                     1250 non-null   object
#  2   Category                  1250 non-null   object
#  3   Location                  1250 non-null   object
#  4   Responsibilities          1235 non-null   object
#  5   Minimum Qualifications    1236 non-null   object
#  6   Preferred Qualifications  1236 non-null   object
# dtypes: object(7)
# memory usage: 68.5+ KB

# %%
print(ds_df["Responsibilities"].isnull().sum())
print(ds_df["Minimum Qualifications"].isnull().sum())
print(ds_df["Preferred Qualifications"].isnull().sum())
# Out:
# 15
# 14
# 14

# %%
ds_df["Category"].unique()
# Out:
# array(['Program Management', 'Manufacturing & Supply Chain',
#        'Technical Solutions', 'Developer Relations',
#        'Hardware Engineering', 'Partnerships',
#        'Product & Customer Support', 'Software Engineering',
#        'Data Center & Network', 'Business Strategy', 'Technical Writing',
#        'Technical Infrastructure', 'IT & Data Management',
#        'Marketing & Communications', 'Network Engineering',
#        'Sales & Account Management', 'Sales Operations', 'Finance',
#        'Legal & Government Relations', 'Administrative',
#        'User Experience & Design', 'People Operations',
#        'Real Estate & Workplace Services'], dtype=object)

# %%
ds_df["Title"].unique()
# Out:
# array(['Google Cloud Program Manager',
#        'Supplier Development Engineer (SDE), Cable/Connector',
#        'Data Analyst, Product and Tools Operations, Google Technical Services',
#        'Developer Advocate, Partner Engineering',
#        'Program Manager, Audio Visual (AV) Deployments',
#        'Associate Account Strategist (Czech/Slovak), Global Customer Experience',
#        'Supplier Development Engineer, Camera, Consumer Hardware',
#        'Strategic Technology Partner Manager, Healthcare and Life Sciences',
#        'Manufacturing Business Manager, Google Hardware',
#        'Solutions Architect, Healthcare and Life Sciences, Google Cloud',
#        'Data Analyst, Consumer Hardware',
#        'Partner Onboarding Manager (Americas)',
#        'Associate Account Strategist (Ukrainian), GMS Sales',
#        'Survey Lead, Google Cloud Support',
#        'Solution Architect, Google Cloud Platform (Apigee)',
#        'Manufacturing Test Engineer',
# ...

# %%
ds_df["Category"].sample(10)
# Out:
# 363                 Sales Operations
# 1146               People Operations
# 358       Sales & Account Management
# 951                          Finance
# 893                Business Strategy
# 267              Technical Solutions
# 70               Technical Solutions
# 1070    Legal & Government Relations
# 491                 Sales Operations
# 309       Sales & Account Management
# Name: Category, dtype: object

# %%
ds_df["Responsibilities"].sample(10)
# Out:
# 373     Design and implement innovative, unique and ro...
# 541     Partner with Field Sales teams early in the sa...
# 909     Work with large, complex YouTube data sets; so...
# 1144    Cultivate an understanding of Google’s product...
# 1069    Coordinate Legal operations escalations across...
# 558     Lead a team of Managers and their teams in Nor...
# 571     Work with Google’s largest customers on projec...
# 78      Become a trusted technical advisor to customer...
# 442     Contribute to account/territory strategy by pe...
# 454     Understand developments/trends in the digital ...
# Name: Responsibilities, dtype: object

# %%
ds_df["Minimum Qualifications"].sample(10)
# Out:
# 821     BA/BS degree in Anthropology, Human Factors, P...
# 618     Must be a first year student in a two year ful...
# 956     BA/BS degree in a technical or quantitative/bu...
# 322     BA/BS degree or equivalent practical experienc...
# 1231    BA/BS degree or equivalent practical experienc...
# 913     BA/BS degree in a technical or quantitative/bu...
# 693     Must be a first year student in a two year ful...
# 1183    BA/BS degree or equivalent practical experienc...
# 110     BA/BS degree in Electrical or Electronic Engin...
# 473     BA/BS degree or equivalent practical experienc...
# Name: Minimum Qualifications, dtype: object

# %%
ds_df["Preferred Qualifications"].sample(10)
# Out:
# 429     Experience building and cultivating lasting re...
# 747     Previous internship experience in Sales, Adver...
# 289     Experience managing digital advertising campai...
# 1077    Juris Doctor degree.\nExperience working in a ...
# 193     MBA or Master's degree.\nExperience developing...
# 604     Global experience in launching and maintaining...
# 1012    Interest in the Internet and Google's technolo...
# 386     MBA degree.\nIndustry knowledge of System Inte...
# 526     Experience working with advertisers, agencies,...
# 477     MBA or equivalent degree.\nExperience working ...
# Name: Preferred Qualifications, dtype: object
